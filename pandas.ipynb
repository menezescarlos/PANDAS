# %% [markdown]
# ### Leitura dos dados
# - read_csv( )

# %%
import pandas as pd

#base_dados = pd.read_csv('c:/')

url = 'https://raw.githubusercontent.com/menezescarlos/ANALISE-RFV/main/new_retail_data.csv'
base_dados = pd.read_csv(url)

# %% [markdown]
# ### Visualização Rápida dos Dados
# - head( )
# - info( )
# - describe( )

# %%
base_dados.head(2)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
#
#           Phone             Address        City    State  Zipcode  Country  \
# 0  1.414787e+09   3959 Amanda Burgs    Dortmund   Berlin  77985.0  Germany
# 1  6.852900e+09  82072 Dawn Centers  Nottingham  England  99071.0       UK
#
#    ...  Total_Amount Product_Category Product_Brand Product_Type   Feedback  \
# 0  ...    324.086270         Clothing          Nike       Shorts  Excellent
# 1  ...    806.707815      Electronics       Samsung       Tablet  Excellent
#
#    Shipping_Method Payment_Method Order_Status  Ratings        products
# 0         Same-Day     Debit Card      Shipped      5.0  Cycling shorts
# 1         Standard    Credit Card   Processing      4.0      Lenovo Tab
#
# [2 rows x 30 columns]

# %%
base_dados.tail(2)
# Out:
#         Transaction_ID  Customer_ID            Name                Email  \
# 302008       9301950.0      45477.0  Patrick Wilson  Rebecca65@gmail.com
# 302009       2882826.0      53626.0  Dustin Merritt  William14@gmail.com
#
#                Phone              Address     City          State  Zipcode  \
# 302008  9.373222e+09      3204 Baird Port  Halifax        Ontario  67608.0
# 302009  9.518927e+09  143 Amanda Crescent   Tucson  West Virginia  25242.0
#
#        Country  ...  Total_Amount Product_Category Product_Brand Product_Type  \
# 302008  Canada  ...    120.834784       Home Decor          IKEA    Furniture
# 302009     USA  ...   2382.233417       Home Decor    Home Depot  Decorations
#
#        Feedback  Shipping_Method Payment_Method Order_Status  Ratings  \
# 302008     Good         Standard           Cash      Shipped      4.0
# 302009  Average         Same-Day           Cash      Shipped      2.0
#
#         products
# 302008  TV stand
# 302009    Clocks
#
# ...

# %%
base_dados.shape
# Out:
# (302010, 30)

# %%
base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
# ...

# %%
base_dados.describe()
# Out:
#        Transaction_ID    Customer_ID         Phone        Zipcode  \
# count    3.016770e+05  301702.000000  3.016480e+05  301670.000000
# mean     5.495823e+06   55006.553934  5.501464e+09   50298.951019
# std      2.595565e+06   26005.675200  2.596017e+09   28972.807134
# min      1.000007e+06   10000.000000  1.000049e+09     501.000000
# 25%      3.247930e+06   32469.250000  3.255061e+09   25425.000000
# 50%      5.499657e+06   55012.000000  5.505812e+09   50602.500000
# 75%      7.739509e+06   77511.000000  7.749860e+09   75252.000000
# max      9.999995e+06   99999.000000  9.999996e+09   99949.000000
#
#                  Age           Year  Total_Purchases         Amount  \
# count  301837.000000  301660.000000    301649.000000  301653.000000
# mean       35.481326    2023.165113         5.359729     255.163659
# std        15.021933       0.371283         2.868575     141.389640
# min        18.000000    2023.000000         1.000000      10.000219
# ...

# %% [markdown]
# ### Seleção de Dados
#
# - loc[ ]
# - iloc[ ]

# %% [markdown]
# ### Manipulação de Dados
# - drop( )
# - sort_values( )
# - groupby( )

# %% [markdown]
# ### Manipulação de Valores Ausentes
# - insull( )
# - fillna( )
# - dropna( )

# %% [markdown]
# ### Junção de DataFrames
# - merge( )

# %% [markdown]
# ### Exportação de Dados
# - to_csv( )
